# %%
from pathlib import Path

import pandas as pd
import tarfile
import urllib.request

def load_housing_data(): # Definición de la función
    tarball_path = Path("datasets/housing.tgz") # creamos un objeto Path con la ruta relativa del archivo que se descargará
    if not tarball_path.is_file(): # si el archivo no existe ya, lo descargamos
        Path("datasets").mkdir(parents=True, exist_ok=True) # crea el directorio datasets si no existe
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path) # descarga el archivo desde la url a la ruta tarball_path
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets") # descomprime el archivo en la ruta datasets
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()

# Show the first 5 rows of the dataset
print(housing.head())
print()

print(housing.info())

housing.info()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
# <class 'pandas.core.frame.DataFrame'>
# ...
