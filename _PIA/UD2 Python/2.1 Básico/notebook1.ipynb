# %% [markdown]
# movida

# %%
print("Hola")
print("Hola")

def suma(  a, b ):
    return a + b


#Show a Christmas tree
def christmas_tree( n ):
    for i in range( n ):
        3/0
        print( " " * ( n - i ), "*" * ( 2 * i + 1 ) )

christmas_tree( 10 )
# Out:
# Hola
# Hola
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\avida\DATOS\TRABAJO\IA\IA\PIA\UD2 Python\notebook1.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/avida/DATOS/TRABAJO/IA/IA/PIA/UD2%20Python/notebook1.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>         3/0
#      <a href='vscode-notebook-cell:/c%3A/Users/avida/DATOS/TRABAJO/IA/IA/PIA/UD2%20Python/notebook1.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>         print( " " * ( n - i ), "*" * ( 2 * i + 1 ) )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/avida/DATOS/TRABAJO/IA/IA/PIA/UD2%20Python/notebook1.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> christmas_tree( 10 )
#
# c:\Users\avida\DATOS\TRABAJO\IA\IA\PIA\UD2 Python\notebook1.ipynb Cell 2 line 1
# ...
